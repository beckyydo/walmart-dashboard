# %%
import pandas as pd
import os
import requests

# %%
store = pd.read_json("data/walmart.json")
store.head()
# Out:
#      id  storeType timeZone          openDate                 name  \
# 0  6601          3        K  01/04/1994 12:00           Sam's Club
# 1  6602          3        K  01/06/1994 12:00           Sam's Club
# 2  2074          1        K  03/29/1994 12:00  Walmart Supercenter
# 3  2070          1        K  03/29/1994 12:00  Walmart Supercenter
# 4  6603          3        K  01/08/1994 12:00           Sam's Club
#
#    postalCode                     address1       city state country  \
# 0       99515          8801 Old Seward Hwy  Anchorage    AK      US
# 1       99504         1074 N. Muldoon Road  Anchorage    AK      US
# 2       99654  1350 S Seward Meridian Pkwy    Wasilla    AK      US
# 3       99503                    3101 A St  Anchorage    AK      US
# 4       99701                48 College Rd  Fairbanks    AK      US
#
#     latitude   longitude    phone_number
# 0  61.140770 -149.860016  (907) 522-2333
# 1  61.231079 -149.740844  (907) 276-2996
# ...

# %%
store = store.loc[(store["storeType"]==1) | (store["storeType"]==2)]
storeLocation = store[['openDate','name','address1','city','state', 'latitude', 'longitude']]
storeLocation.head()
# Out:
#            openDate                 name                     address1  \
# 2  03/29/1994 12:00  Walmart Supercenter  1350 S Seward Meridian Pkwy
# 3  03/29/1994 12:00  Walmart Supercenter                    3101 A St
# 5  03/29/1994 12:00  Walmart Supercenter          8900 Old Seward Hwy
# 6  04/26/2000 12:00  Walmart Supercenter         18600 Eagle River Rd
# 7  09/12/2007 12:00  Walmart Supercenter             6525 Glacier Hwy
#
#           city state   latitude   longitude
# 2      Wasilla    AK  61.568752 -149.363647
# 3    Anchorage    AK  61.192337 -149.880356
# 5    Anchorage    AK  61.140263 -149.868835
# 6  Eagle River    AK  61.309483 -149.534912
# 7       Juneau    AK  58.358349 -134.514862

# %%
storeLocation.to_csv('data/storeLocation.csv', index=False)

# %%
location = pd.read_csv('data/storelocation.csv')
location.head()
# Out:
#            openDate                 name                     address1  \
# 0  03/29/1994 12:00  Walmart Supercenter  1350 S Seward Meridian Pkwy
# 1  03/29/1994 12:00  Walmart Supercenter                    3101 A St
# 2  03/29/1994 12:00  Walmart Supercenter          8900 Old Seward Hwy
# 3  04/26/2000 12:00  Walmart Supercenter         18600 Eagle River Rd
# 4  09/12/2007 12:00  Walmart Supercenter             6525 Glacier Hwy
#
#           city state   latitude   longitude
# 0      Wasilla    AK  61.568752 -149.363647
# 1    Anchorage    AK  61.192337 -149.880356
# 2    Anchorage    AK  61.140263 -149.868835
# 3  Eagle River    AK  61.309483 -149.534912
# 4       Juneau    AK  58.358349 -134.514862
